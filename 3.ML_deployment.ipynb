# %%
# Upgrade Oracle ADS to pick up latest features and maintain compatibility with Oracle Cloud Infrastructure.

# !pip install -U oracle-ads
# !pip install --upgrade oci
# Out:
# Requirement already satisfied: oracle-ads in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (2.8.5)
# Requirement already satisfied: psutil>=5.7.2 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oracle-ads) (5.9.0)
# Requirement already satisfied: python-jsonschema-objects>=0.3.13 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oracle-ads) (0.4.1)
# Requirement already satisfied: oci>=2.102.0 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oracle-ads) (2.104.0)
# Requirement already satisfied: tqdm>=4.59.0 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oracle-ads) (4.64.1)
# Requirement already satisfied: matplotlib>=3.1.3 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oracle-ads) (3.5.2)
# Requirement already satisfied: fsspec>=0.8.7 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oracle-ads) (2022.7.1)
# Requirement already satisfied: tabulate>=0.8.9 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oracle-ads) (0.8.10)
# Requirement already satisfied: numpy>=1.19.2 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oracle-ads) (1.23.3)
# Requirement already satisfied: pandas<1.6,>1.2.1 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oracle-ads) (1.5.3)
# Requirement already satisfied: asteval>=0.9.25 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oracle-ads) (0.9.27)
# Requirement already satisfied: gitpython>=3.1.2 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oracle-ads) (3.1.18)
# Requirement already satisfied: PyYAML<6,>=5.4 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oracle-ads) (5.4.1)
# Requirement already satisfied: ocifs>=1.1.3 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oracle-ads) (1.1.3)
# Requirement already satisfied: jinja2>=2.11.2 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oracle-ads) (3.0.3)
# Requirement already satisfied: requests in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oracle-ads) (2.28.1)
# Requirement already satisfied: cloudpickle>=1.6.0 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oracle-ads) (2.0.0)
# Requirement already satisfied: cerberus>=1.3.4 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oracle-ads) (1.3.4)
# Requirement already satisfied: scikit-learn<1.2,>=0.23.2 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oracle-ads) (1.1.2)
# Requirement already satisfied: setuptools in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from cerberus>=1.3.4->oracle-ads) (65.5.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from gitpython>=3.1.2->oracle-ads) (4.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from jinja2>=2.11.2->oracle-ads) (2.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from matplotlib>=3.1.3->oracle-ads) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from matplotlib>=3.1.3->oracle-ads) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from matplotlib>=3.1.3->oracle-ads) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from matplotlib>=3.1.3->oracle-ads) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from matplotlib>=3.1.3->oracle-ads) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from matplotlib>=3.1.3->oracle-ads) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from matplotlib>=3.1.3->oracle-ads) (3.0.9)
# Requirement already satisfied: cryptography<40.0.0,>=3.2.1 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oci>=2.102.0->oracle-ads) (37.0.2)
# Requirement already satisfied: circuitbreaker<2.0.0,>=1.3.1 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oci>=2.102.0->oracle-ads) (1.4.0)
# Requirement already satisfied: certifi in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oci>=2.102.0->oracle-ads) (2022.9.24)
# Requirement already satisfied: pytz>=2016.10 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oci>=2.102.0->oracle-ads) (2022.6)
# Requirement already satisfied: pyOpenSSL<24.0.0,>=17.5.0 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oci>=2.102.0->oracle-ads) (22.0.0)
# Requirement already satisfied: jsonschema>=2.3 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from python-jsonschema-objects>=0.3.13->oracle-ads) (4.7.2)
# Requirement already satisfied: inflection>=0.2 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from python-jsonschema-objects>=0.3.13->oracle-ads) (0.5.1)
# Requirement already satisfied: six>=1.5.2 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from python-jsonschema-objects>=0.3.13->oracle-ads) (1.16.0)
# Requirement already satisfied: Markdown>=2.4 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from python-jsonschema-objects>=0.3.13->oracle-ads) (3.4.1)
# Requirement already satisfied: scipy>=1.3.2 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from scikit-learn<1.2,>=0.23.2->oracle-ads) (1.9.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from scikit-learn<1.2,>=0.23.2->oracle-ads) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from scikit-learn<1.2,>=0.23.2->oracle-ads) (1.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from requests->oracle-ads) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from requests->oracle-ads) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from requests->oracle-ads) (3.4)
# Requirement already satisfied: cffi>=1.12 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from cryptography<40.0.0,>=3.2.1->oci>=2.102.0->oracle-ads) (1.14.6)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.2->oracle-ads) (3.0.5)
# Requirement already satisfied: importlib-resources>=1.4.0 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from jsonschema>=2.3->python-jsonschema-objects>=0.3.13->oracle-ads) (5.10.0)
# Requirement already satisfied: attrs>=17.4.0 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from jsonschema>=2.3->python-jsonschema-objects>=0.3.13->oracle-ads) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from jsonschema>=2.3->python-jsonschema-objects>=0.3.13->oracle-ads) (0.19.2)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from Markdown>=2.4->python-jsonschema-objects>=0.3.13->oracle-ads) (5.0.0)
# Requirement already satisfied: pycparser in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from cffi>=1.12->cryptography<40.0.0,>=3.2.1->oci>=2.102.0->oracle-ads) (2.21)
# Requirement already satisfied: zipp>=0.5 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from importlib-metadata>=4.4->Markdown>=2.4->python-jsonschema-objects>=0.3.13->oracle-ads) (3.10.0)
# Requirement already satisfied: oci in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (2.104.0)
# Collecting oci
#   Using cached oci-2.104.1-py3-none-any.whl (20.1 MB)
# Requirement already satisfied: circuitbreaker<2.0.0,>=1.3.1 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oci) (1.4.0)
# Requirement already satisfied: cryptography<40.0.0,>=3.2.1 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oci) (37.0.2)
# Requirement already satisfied: certifi in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oci) (2022.9.24)
# Requirement already satisfied: pytz>=2016.10 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oci) (2022.6)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.5.3 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oci) (2.8.2)
# Requirement already satisfied: pyOpenSSL<24.0.0,>=17.5.0 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from oci) (22.0.0)
# Requirement already satisfied: cffi>=1.12 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from cryptography<40.0.0,>=3.2.1->oci) (1.14.6)
# Requirement already satisfied: six>=1.5 in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from python-dateutil<3.0.0,>=2.5.3->oci) (1.16.0)
# Requirement already satisfied: pycparser in /home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages (from cffi>=1.12->cryptography<40.0.0,>=3.2.1->oci) (2.21)
# Installing collected packages: oci
#   Attempting uninstall: oci
#     Found existing installation: oci 2.104.0
#     Uninstalling oci-2.104.0:
#       Successfully uninstalled oci-2.104.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# oci-cli 3.20.1 requires oci==2.88.0, but you have oci 2.104.1 which is incompatible.
# Successfully installed oci-2.104.1

# %%
# 필요 라이브러리 Import

import ads
import logging
import os
import tempfile
import warnings
import json
import base64
import numpy as np
import pandas as pd
import nltk
nltk.download('omw-1.4')
import joblib

import ocifs
import oci
from ocifs import OCIFileSystem

from ads.catalog.model import ModelCatalog
from ads.common.model_metadata import UseCaseType
from ads.common.model_artifact import ModelArtifact
from ads.common.model_export_util import prepare_generic_model
from ads.model.framework.sklearn_model import SklearnModel

from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer

from nltk.stem import WordNetLemmatizer

# Using resource principal to authenticate when using the model catalog. By default, ADS 
# uses the config+key flow to authenticate against the model catalog. Remove this line 
# if you want to use the config+key authn method. 
ads.set_auth(auth='resource_principal')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/datascience/nltk_data...

# %% [markdown]
# <font color=gray>Oracle Data Science service sample notebook.
#
# Copyright (c) 2023 Oracle, Inc.  All rights reserved.
# Licensed under the Universal Permissive License v 1.0 as shown at https://oss.oracle.com/licenses/upl.
# </font>
#
# ***
# # <font color=red>Sklearn으로 만들 모델 배포하기</font>
# <p style="margin-left:10%; margin-right:10%;">by the <font color=teal> Oracle Cloud Infrastructure Data Science Service Team </font></p>
#
# ***
#
# ## Overview:
#
# Accelerated Data Science(ADS)의 'SklearnModel' 클래스는 모델을 신속하게 생성하고 배포할 수 있도록 설계되었습니다.
# - `.prepare()` 메서드는 모델을 구성하거나 코드를 작성할 필요 없이 작동하는 모델을 배포하는 데 필요한 모델 아티팩트를 생성합니다.
# - `score.py` 파일은 필요에 따라 사용자 정의할 수 있습니다.
# - `.verify()` 메서드를 사용하여 배포된 모델에 대한 호출을 시뮬레이션합니다. 이 메서드는 `score.py` 파일에서 `load_model()` 및 `predict()` 함수를 호출합니다. `.verify()`를 사용하면 모델을 배포하지 않고도 `score.py` 파일을 디버그할 수 있습니다.
# - `.save()` 메서드는 `SklearnModel` 및 모델 아티팩트를 모델 카탈로그로 푸시합니다.
# - `.deploy()` 메서드는 모델을 REST 끝점에 배포합니다.
# - `.predict()` 메서드를 사용하면 엔드포인트를 호출하여 모델 추론을 수행할 수 있습니다.
#
# ---

# %% [markdown]
# <a id='intro'></a>
# # Introduction
#
# ## Authenticate
#
# OCI Data Science 서비스에 대한 인증이 필요합니다. 여기서는 기본적으로 리소스 주체를 사용합니다.

# %%
ads.set_auth(auth="resource_principal")

# %% [markdown]
# <a id="intro_dataset"></a>
# ## Create Dataset

# %%
# Bucket에 있는 크롤링 데이터 import
# 한국어 및 테스트 데이터 삭제 
# nan과 null 데이터 처리를 위해 desc열만 dataframe으로 변환 

crawled_parquet_df = pd.read_json("oci://crawled_data@apackrsct01/data_20230307.json")
df_final=crawled_parquet_df.drop([404,412,466,772])
df_final1 = pd.DataFrame({'document':df_final.desc})
df_final2 = df_final1.dropna()
df_final3 = df_final2[df_final2['document'].astype(bool)]
crawled_final = list(df_final3.document.values)

# %%
# CountVectorizer로 벡터화기 구현
# 최종 데이터 crwaled_final을 transform 후 LDA 알고리즘으로 Topic Modeling 생성

lemm = WordNetLemmatizer()

class LemmaCountVectorizer(CountVectorizer):
    def build_analyzer(self):
        analyzer = super(LemmaCountVectorizer, self).build_analyzer()
        return lambda doc: (lemm.lemmatize(w) for w in analyzer(doc))
    
tf_vectorizer = LemmaCountVectorizer(max_df=0.95, 
                                     min_df=2,
                                     stop_words='english',
                                     decode_error='ignore')

tf = tf_vectorizer.fit_transform(crawled_final)

model = LatentDirichletAllocation(n_components=11, max_iter=10,
                                learning_method = 'online',
                                learning_offset = 50.,
                                random_state = 0)
model.fit(tf)
# Out:
# LatentDirichletAllocation(learning_method='online', learning_offset=50.0,
#                           n_components=11, random_state=0)

# %%
#Topic modeling data 결과

doc_topics=model.transform(tf)

topic_index=list(df_final3.index.values)
topic_names = ['Topic #'+str(i) for i in range(0,11)]
topic_df = pd.DataFrame(data=doc_topics, columns=topic_names,index=topic_index)

dominant_topic = np.argmax(topic_df.values, axis=1)
topic_df['dominant_topic'] = dominant_topic
topic_df.head(20)
# Out:
#     Topic #0  Topic #1  Topic #2  Topic #3  Topic #4  Topic #5  Topic #6  \
# 0   0.001653  0.001653  0.001653  0.001653  0.001653  0.001653  0.001653
# 1   0.003135  0.003135  0.003135  0.003135  0.003135  0.003135  0.003135
# 2   0.003135  0.003135  0.003135  0.003135  0.003135  0.003135  0.003135
# 3   0.001443  0.001443  0.001443  0.001443  0.001443  0.001443  0.001443
# 4   0.005348  0.005348  0.005348  0.005349  0.005348  0.005348  0.005348
# 5   0.002217  0.002217  0.687588  0.002217  0.002217  0.002217  0.002217
# 6   0.002165  0.002165  0.002165  0.002165  0.002165  0.028282  0.002165
# 7   0.002841  0.002841  0.002841  0.002841  0.002841  0.002841  0.002841
# 8   0.004785  0.004785  0.004785  0.004785  0.004786  0.004785  0.004785
# 9   0.002674  0.002674  0.002674  0.002674  0.002674  0.002674  0.002674
# 10  0.001541  0.001541  0.001541  0.001541  0.001541  0.001541  0.001541
# 11  0.002217  0.002217  0.002218  0.002217  0.002217  0.002217  0.002217
# 12  0.003788  0.003788  0.003788  0.003788  0.274231  0.003788  0.003788
# 13  0.002841  0.002841  0.002841  0.002841  0.002841  0.002841  0.002841
# 14  0.009091  0.009091  0.104395  0.009091  0.009093  0.009091  0.009091
# 15  0.004545  0.004545  0.004545  0.004546  0.004546  0.004546  0.004545
# 16  0.005348  0.005348  0.005348  0.005348  0.005348  0.136213  0.005348
# 17  0.002841  0.002841  0.002841  0.002841  0.002841  0.002841  0.002841
# 18  0.007576  0.007576  0.007576  0.007579  0.007576  0.007576  0.007576
# 19  0.012987  0.012987  0.012987  0.012988  0.012987  0.012989  0.012987
#
#     Topic #7  Topic #8  Topic #9  Topic #10  dominant_topic
# 0   0.055694  0.001653  0.929429   0.001653               9
# 1   0.003135  0.003135  0.968651   0.003135               9
# 2   0.003135  0.003135  0.968652   0.003135               9
# 3   0.001443  0.001443  0.985570   0.001443               9
# 4   0.005348  0.005348  0.946521   0.005348               9
# 5   0.002217  0.002217  0.292456   0.002217               2
# 6   0.002165  0.002165  0.952237   0.002165               9
# 7   0.002841  0.002841  0.971590   0.002841               9
# 8   0.004785  0.004785  0.952151   0.004785               9
# 9   0.002674  0.002674  0.973262   0.002674               9
# 10  0.001541  0.001541  0.984591   0.001541               9
# 11  0.002217  0.002217  0.977826   0.002217               9
# 12  0.003788  0.003788  0.691677   0.003788               9
# 13  0.002841  0.002841  0.971590   0.002841               9
# 14  0.009092  0.009091  0.813783   0.009091               9
# 15  0.004546  0.004546  0.954544   0.004545               9
# 16  0.005348  0.005348  0.815658   0.005348               9
# 17  0.002841  0.002841  0.971590   0.002841               9
# 18  0.007577  0.007576  0.924237   0.007576               9
# 19  0.012987  0.012987  0.870126   0.012987               9

# %%
X=topic_df.drop(['dominant_topic'],axis=1)
y=topic_df['dominant_topic']

#importing train_test_split
from sklearn.model_selection import train_test_split
trainx, trainy, testx, testy = train_test_split(X,y,test_size=1/3,random_state=42, stratify=y)

# %% [markdown]
# ## 모델 생성

# %%
model = KMeans(
     init="random",
     n_clusters=5,
     n_init=10,
     max_iter=300,
     random_state=42
 )

model.fit(trainx)
# Out:
# KMeans(init='random', n_clusters=5, random_state=42)

# %% [markdown]
# ## 모델 준비
#
# 데이터를 위한 임시 디렉토리 생성

# %%
artifact_dir = tempfile.mkdtemp()
sklearn_model = SklearnModel(estimator=model, artifact_dir=artifact_dir)
sklearn_model.prepare(
    inference_conda_env="generalml_p38_cpu_v1",
    training_conda_env="generalml_p38_cpu_v1",
    use_case_type=UseCaseType.CLUSTERING,
    X_sample=trainx,
    y_sample=trainy,
    force_overwrite=True,
)
# Out:
# WARNING:ads.common:In the future model input will be serialized by `cloudpickle` by default. Currently, model input are serialized into a dictionary containing serialized input data and original data type information.Set `model_input_serializer="cloudpickle"` to use cloudpickle model input serializer.
# WARNING:ADS:No commit found.                                                                                                                                                                                          ?, ?it/s]
# algorithm: KMeans
# artifact_dir:
#   /tmp/tmpyh92dugk:
#   - - runtime.yaml
#     - score.py
#     - .model-ignore
#     - input_schema.json
#     - output_schema.json
#     - model.joblib
# framework: scikit-learn
# model_deployment_id: null
# model_id: null

# %%
sklearn_model.summary_status()
# Out:
#                                                                             Actions Needed
# Step      Status        Details
# initiate  Done          Initiated the model
# prepare() Done          Generated runtime.yaml
#                         Generated score.py
#                         Serialized model
#                         Populated metadata(Custom, Taxonomy and Provenance)
# verify()  Available     Local tested .predict from score.py
# save()    Available     Conducted Introspect Test
#                         Uploaded artifact to model catalog
# deploy()  UNKNOWN       Deployed the model
# predict() Not Available Called deployment predict endpoint

# %% [markdown]
# ## Verify
#
# verify 메서드는 artifact_dir의 ``score.py`` 내부에 정의된 ``predict`` 함수를 호출합니다.

# %%
sklearn_model.verify(trainx[:10])
# Out:
# Start loading model.joblib from model directory /tmp/tmpyh92dugk ...
# Model is successfully loaded.
# {'prediction': [3, 3, 3, 3, 3, 3, 3, 3, 3, 2]}

# %% [markdown]
# ## Save

# %%
sklearn_model.save(display_name="livelab-clustering")
# Out:
# Start loading model.joblib from model directory /tmp/tmpyh92dugk ...
# Model is successfully loaded.
# ['runtime.yaml', 'score.py', '.model-ignore', 'input_schema.json', 'output_schema.json', 'model.joblib']
# loop1:   0%|          | 0/4 [00:00<?, ?it/s]
# 'ocid1.datasciencemodel.oc1.ap-tokyo-1.amaaaaaavsea7yia5edudgc76rppsfuhaexmooltcb4xbagsppobtitvyiaa'

# %%
sklearn_model.summary_status()
# Out:
#                                                                             Actions Needed
# Step      Status        Details
# initiate  Done          Initiated the model
# prepare() Done          Generated runtime.yaml
#                         Generated score.py
#                         Serialized model
#                         Populated metadata(Custom, Taxonomy and Provenance)
# verify()  Done          Local tested .predict from score.py
# save()    Done          Conducted Introspect Test
#                         Uploaded artifact to model catalog
# deploy()  UNKNOWN       Deployed the model
# predict() Not Available Called deployment predict endpoint

# %% [markdown]
# ## Deploy
#
# 모델이 모델 카탈로그에 있으면 모델의 `.deploy()` 메서드를 사용하여 배포할 수 있습니다.
# 이 방법을 사용하면 표시 이름, 설명, 인스턴스 유형 및 개수, 최대 대역폭, 로깅 그룹과 같은 배포 속성을 지정할 수 있습니다.
# 다음 셀은 사용자 지정 표시 이름을 제외한 기본 설정으로 모델을 배포합니다.
# `.deploy()` 메서드는 `ModelDeployment` 개체를 반환합니다.

# %%
deploy = sklearn_model.deploy(
    display_name="KMeans Clustering for Crawled Livelabs",
)
# Out:
# loop1:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
sklearn_model.summary_status()
# Out:
#                                                                         Actions Needed
# Step      Status    Details
# initiate  Done      Initiated the model
# prepare() Done      Generated runtime.yaml
#                     Generated score.py
#                     Serialized model
#                     Populated metadata(Custom, Taxonomy and Provenance)
# verify()  Done      Local tested .predict from score.py
# save()    Done      Conducted Introspect Test
#                     Uploaded artifact to model catalog
# deploy()  ACTIVE    Deployed the model
# predict() Available Called deployment predict endpoint

# %%
print(f"Endpoint: {sklearn_model.model_deployment.url}")
# Out:
# Endpoint: https://modeldeployment.ap-tokyo-1.oci.customer-oci.com/ocid1.datasciencemodeldeployment.oc1.ap-tokyo-1.amaaaaaavsea7yiaaeinhv4qgq7clswtnc7f6ochhc57e7vcd6bmprxxnxja

# %% [markdown]
# ## Predict
#
# 배포가 활성화되면 모델 객체에서 `predict()`를 호출하여 배포된 엔드포인트에 요청을 보낼 수 있습니다.

# %%
sklearn_model.predict(testx)
# Out:
# '{"code": "InternalServerError", "message": "Expected 2D array, got 1D array instead:\\narray=[9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 7. 9. 9. 9. 9. 9. 2. 9. 9. 9. 9.\\n 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 7. 9. 9. 9. 9. 9. 9. 9.\\n 9. 9. 9. 5. 9. 9. 9. 9. 4. 9. 4. 4. 3. 9. 9. 4. 9. 9. 9. 9. 9. 9. 9. 9.\\n 9. 9. 9. 2. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 8. 9. 9. 9. 9. 9. 9. 9. 9.\\n 2. 9. 4. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 2. 9. 9. 4. 3. 3. 9. 9. 9. 3. 9.\\n 4. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 2. 9. 9. 9.\\n 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 4. 2.\\n 9. 4. 9. 9. 9. 9. 9. 2. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 8. 9. 9. 9.\\n 9. 9. 9. 9. 9. 9. 4. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 4. 9. 2. 9. 9. 9. 9.\\n 9. 9. 4. 9. 9. 9. 9. 9. 9. 9. 9. 3. 4. 9. 9. 9. 9. 3. 9. 9. 9. 5. 9. 9.\\n 9. 9. 9. 9. 9. 9. 5. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9.\\n 9. 9. 9. 9. 9. 5. 9. 9. 9. 3. 9. 9. 9. 9. 9. 9. 9. 4. 9. 9. 9. 9. 9. 9.\\n 9. 3. 2. 9. 9. 9. 9. 9. 9. 9. 9. 9. 3. 9. 4. 9. 9. 9. 9. 7. 9. 9. 9. 9.\\n 9. 9. 9. 9.].\\nReshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.", "status": "Expected 2D array, got 1D array instead:\\narray=[9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 7. 9. 9. 9. 9. 9. 2. 9. 9. 9. 9.\\n 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 7. 9. 9. 9. 9. 9. 9. 9.\\n 9. 9. 9. 5. 9. 9. 9. 9. 4. 9. 4. 4. 3. 9. 9. 4. 9. 9. 9. 9. 9. 9. 9. 9.\\n 9. 9. 9. 2. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 8. 9. 9. 9. 9. 9. 9. 9. 9.\\n 2. 9. 4. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 2. 9. 9. 4. 3. 3. 9. 9. 9. 3. 9.\\n 4. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 2. 9. 9. 9.\\n 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 4. 2.\\n 9. 4. 9. 9. 9. 9. 9. 2. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 8. 9. 9. 9.\\n 9. 9. 9. 9. 9. 9. 4. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 4. 9. 2. 9. 9. 9. 9.\\n 9. 9. 4. 9. 9. 9. 9. 9. 9. 9. 9. 3. 4. 9. 9. 9. 9. 3. 9. 9. 9. 5. 9. 9.\\n 9. 9. 9. 9. 9. 9. 5. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9. 9.\\n 9. 9. 9. 9. 9. 5. 9. 9. 9. 3. 9. 9. 9. 9. 9. 9. 9. 4. 9. 9. 9. 9. 9. 9.\\n 9. 3. 2. 9. 9. 9. 9. 9. 9. 9. 9. 9. 3. 9. 4. 9. 9. 9. 9. 7. 9. 9. 9. 9.\\n 9. 9. 9. 9.].\\nReshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample."}'

# %% [markdown]
# <a id='clean_up'></a>
# # Clean Up
#
# 이 노트북은 모델 배포와 모델을 만들었습니다. 이 섹션에서는 해당 리소스를 정리합니다.
#
# 모델을 삭제하려면 먼저 모델 배포를 삭제해야 합니다. 이를 수행하려면 `SklearnModel` 개체에서 `.delete_deployment()` 메서드를 사용합니다.

# %%
delete = sklearn_model.delete_deployment(wait_for_completion=True)
# Out:
# loop1:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# 모델 배포가 삭제된 후 `.summary_status()` 메서드는 모델이 삭제되었고 `predict()` 메서드를 사용할 수 없음을 보여줍니다.

# %%
sklearn_model.summary_status()
# Out:
#                                                                             Actions Needed
# Step      Status        Details
# initiate  Done          Initiated the model
# prepare() Done          Generated runtime.yaml
#                         Generated score.py
#                         Serialized model
#                         Populated metadata(Custom, Taxonomy and Provenance)
# verify()  Done          Local tested .predict from score.py
# save()    Done          Conducted Introspect Test
#                         Uploaded artifact to model catalog
# deploy()  DELETED       Deployed the model
# predict() Not Available Called deployment predict endpoint

# %% [markdown]
# `.delete()` 메서드를 사용하여 모델을 삭제합니다.

# %%
sklearn_model.delete()

# %% [markdown]
# 다음 셀은 로컬 드라이브에 저장된 모델 아티팩트를 제거합니다.

# %%
rmtree(artifact_dir)

# %% [markdown]
# <a id='ref'></a>
# # References
# - [ADS Library Documentation](https://accelerated-data-science.readthedocs.io/en/latest/index.html)
# - [Data Science YouTube Videos](https://www.youtube.com/playlist?list=PLKCk3OyNwIzv6CWMhvqSB_8MLJIZdO80L)
# - [OCI Data Science Documentation](https://docs.cloud.oracle.com/en-us/iaas/data-science/using/data-science.htm)
# - [Oracle Data & AI Blog](https://blogs.oracle.com/datascience/)
# - [Understanding Conda Environments](https://docs.cloud.oracle.com/en-us/iaas/data-science/using/use-notebook-sessions.htm#conda_understand_environments)
# - [Use Resource Manager to Configure Your Tenancy for Data Science](https://docs.cloud.oracle.com/en-us/iaas/data-science/using/orm-configure-tenancy.htm)
# - [`runtime.yaml`](https://docs.content.oci.oracleiaas.com/en-us/iaas/data-science/using/model_runtime_yaml.htm#model_runtime_yaml)
# - [`score.py`](https://docs.content.oci.oracleiaas.com/en-us/iaas/data-science/using/model_score_py.htm#model_score_py)
# - [Model artifact](https://docs.content.oci.oracleiaas.com/en-us/iaas/data-science/using/models_saving_catalog.htm#create-models)
# - [ONNX API Summary](http://onnx.ai/sklearn-onnx/api_summary.html)
